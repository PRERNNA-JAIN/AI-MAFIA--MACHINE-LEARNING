# %%
import smtplib
import getpass
from email.mime.text import MIMEText


def send_email():
    sender_adress = 'prernnajain3025@gmail.com'
    password = getpass.getpass()

    print(password)
    subject="LEARN . INSPIRE. GROW"
    msg=''' hello everyone !
       we are pleased to announce that we are going to start a new batch
       of AI Mafia ,hope you will join
       Thank you!
       
       '''
    #server initialisation

    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.starttls()#allow your connection
    server.login(sender_adress, password)
    recipients = ['d20z128@psgitech.ac.in', 'prernnajain3025@gmail.com']

    #draft my message body
    msg=MIMEText(msg)
    msg['Subject'] = subject
    msg['From'] = sender_adress
    msg['To'] = ",".join(recipients)
    msg.set_param('importance', 'high value')
    #recipients = ['d20z128@psgitech.ac.in', 'prernnajain3025@gmail.com']
    server.sendmail(sender_adress, recipients, msg.as_string ())
    import socket
    socket.getaddrinfo('localhost',25)
send_email()
# Out:
# ········
# apple123
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# <ipython-input-7-d0be22b2e9f6> in <module>
#      33     import socket
#      34     socket.getaddrinfo('localhost',25)
# ---> 35 send_email()
#      36
#
# <ipython-input-7-d0be22b2e9f6> in send_email()
#      18     #server initialisation
#      19
# ---> 20     server = smtplib.SMTP('smtp.gmail.com', 587)
#      21     server.starttls()#allow your connection
#      22     server.login(sender_adress, password)
#
# ~\anaconda3\lib\smtplib.py in __init__(self, host, port, local_hostname, timeout, source_address)
#     251
#     252         if host:
# --> 253             (code, msg) = self.connect(host, port)
#     254             if code != 220:
#     255                 self.close()
#
# ~\anaconda3\lib\smtplib.py in connect(self, host, port, source_address)
# ...

# %%
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
from pandas import Series,DataFrame

# %%
url='https://www.timeanddate.com/weather/india'

# %%
#calling the API server using request module
result=requests.get(url)
#print(result.content)
soup=BeautifulSoup(result.content,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--
# scripts and programs that download content transparent to the user are not allowed without permission
# --><html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>Weather in India</title><meta content="Current weather in India, with temperatures in 367 cities, including high and low temperatures for the country." name="description"/><meta content="https://www.timeanddate.com/scripts/cityog.php?title=Weather%20in&amp;tint=0x007b7a&amp;country=India&amp;image=new-delhi1" property="og:image"/><meta content="1366" property="og:image:width"/><meta content="738" property="og:image:height"/><meta content="website" property="og:type"/><style>
# ...

# %%
summary=content.find('div')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-65d5950b398c> in <module>
# ----> 1 summary=content.find('div')
#
# NameError: name 'content' is not defined

# %%
summary=soup.find('div')

# %%
print(content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-017556a809df> in <module>
# ----> 1 print(content)
#
# NameError: name 'content' is not defined

# %%
content=soup.find('div')
print(content)
# Out:
# <div class="header__wrapper" id="header__wrapper"><div class="header__inner" id="header__inner"><div class="banner" id="header"><div class="fixed"><div id="logo"><a href="/" rel="home"><img alt="timeanddate.com" height="88" src="//c.tadst.com/gfx/n/tad-logo-com3.png" title="Home page timeanddate.com" width="170"/></a></div></div></div><div id="ad-wrap"><div class="fixed" id="ad-wrap2"><div id="ad7"><div id="div-gpt-com-728x90" style="width:728px;height:90px;"><script>
# googletag.cmd.push(function(){googletag.display('div-gpt-com-728x90'); });
# </script>
# ...

# %%
content=soup.find('section')
print(content)
# Out:
# <section class="headline-banner__wrap">
# <img alt="Flag for India" class="headline-banner__flag" height="32" src="//c.tadst.com/gfx/n/fl/48/in.png" title="Flag for India" width="48"/>
# <div class="headline-banner__content"><h1 class="headline-banner__title">Weather in India</h1></div></section>

# %%
content=soup.find(class='layout-grid_main tpl-banner_content')
print(content)
# Out:
#   File "<ipython-input-21-825bc802997a>", line 1
#     content=soup.find(class='layout-grid_main tpl-banner_content')
#                       ^
# SyntaxError: invalid syntax

# %%
content=soup.find('layout-grid_main tpl-banner_content')
print(content)
# Out:
# None

# %%
content=soup.find('layout-grid_hero tpl-banner_hero')
print(content)
# Out:
# None

# %%
content=soup.find(script)
print(content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-f1abf541190f> in <module>
# ----> 1 content=soup.find(script)
#       2 print(content)
#
# NameError: name 'script' is not defined

# %%
print(len(content))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fe4d102ab986> in <module>
# ----> 1 print(len(content))
#
# TypeError: object of type 'NoneType' has no len()

# %%
content=soup.find('section')
print(len(content)
# Out:
#   File "<ipython-input-26-598f5f1b7402>", line 2
#     print(len(content)
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
content=soup.find('section')
print(len(content))
# Out:
# 4

# %%
content=soup.find('div')
print(len(content))
# Out:
# 1

# %%
summary=content[1].find(class='layout-grid_main tpl-banner_content')
print(summary)
# Out:
#   File "<ipython-input-31-3e0dad477c71>", line 1
#     summary=content[1].find(class='layout-grid_main tpl-banner_content')
#                             ^
# SyntaxError: invalid syntax

# %%
series=[ele.get_text() for ele in l]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1bb1200b60e7> in <module>
# ----> 1 series=[ele.get_text() for ele in l]
#
# NameError: name 'l' is not defined

# %%
content=soup.find(class_="layout-grid_main tpl-banner_content')
print(content)
# Out:
#   File "<ipython-input-35-3e3eb8542a75>", line 1
#     content=soup.find(class_="layout-grid_main tpl-banner_content')
#                                                                    ^
# SyntaxError: EOL while scanning string literal

# %%
content=soup.find(class_="layout-grid_main tpl-banner_content")
print(content)
# Out:
# None

# %%
content=soup.find(class_=" tpl-banner weather")
print(content)
# Out:
# None

# %%
content=soup.findall('class')
print(content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-f17dca019ae7> in <module>
# ----> 1 content=soup.findall('class')
#       2 print(content)
#
# TypeError: 'NoneType' object is not callable

# %%
content=soup.findall('div')
print(content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-2f6e8b3d024c> in <module>
# ----> 1 content=soup.findall('div')
#       2 print(content)
#
# TypeError: 'NoneType' object is not callable

# %%
content=soup.find('div')
print(content)
# Out:
# <div class="header__wrapper" id="header__wrapper"><div class="header__inner" id="header__inner"><div class="banner" id="header"><div class="fixed"><div id="logo"><a href="/" rel="home"><img alt="timeanddate.com" height="88" src="//c.tadst.com/gfx/n/tad-logo-com3.png" title="Home page timeanddate.com" width="170"/></a></div></div></div><div id="ad-wrap"><div class="fixed" id="ad-wrap2"><div id="ad7"><div id="div-gpt-com-728x90" style="width:728px;height:90px;"><script>
# googletag.cmd.push(function(){googletag.display('div-gpt-com-728x90'); });
# </script>
# ...

# %%
content=soup.find('section')
print(content)
# Out:
# <section class="headline-banner__wrap">
# <img alt="Flag for India" class="headline-banner__flag" height="32" src="//c.tadst.com/gfx/n/fl/48/in.png" title="Flag for India" width="48"/>
# <div class="headline-banner__content"><h1 class="headline-banner__title">Weather in India</h1></div></section>

# %%
content=soup.findall('h1')
print(content)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-b15f9cf89670> in <module>
# ----> 1 content=soup.findall('h1')
#       2 print(content)
#
# TypeError: 'NoneType' object is not callable

# %%
content=soup.find('script')
print(content)
# Out:
# <script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
